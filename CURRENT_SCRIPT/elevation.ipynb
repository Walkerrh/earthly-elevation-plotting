# %%
import rasterio

file = rasterio.open(r"C:\Users\razer\Desktop\topg_europa\tif\10_DEM_y80x90.tif")
dataset = file.read()
print(dataset.shape)
# Out:
# (1, 2401, 2401)

# %%
from rasterio.plot import show

show(dataset, cmap='terrain')
# Out:
# <Axes: >

# %%
import tifffile as tiff

image_array = dataset
tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run.tif", image_array)
# Out:
# C:\Users\razer\AppData\Local\Temp\ipykernel_36608\216447986.py:4: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run.tif", image_array)

# %%
from shapely.geometry import box
from rasterio.mask import mask

bbox = box(
    minx=500, 
    miny=500, 
    maxx=2000, 
    maxy=2000
    ) #xmin, ymin, xmax, ymax

with rasterio.open(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run.tif") as src:
    out_image, out_transform = mask(src, [bbox], crop=True)
    out_meta = src.meta.copy()

show(out_image, cmap='terrain')
# Out:
# c:\Users\razer\AppData\Local\Programs\Python\Python311\Lib\site-packages\rasterio\__init__.py:317: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# <Axes: >

# %%
cropped_tiff = out_image

tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_cropped.tif", cropped_tiff)
# Out:
# C:\Users\razer\AppData\Local\Temp\ipykernel_36608\2644993046.py:3: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_cropped.tif", cropped_tiff)

# %%
from shapely.geometry import box
from rasterio.mask import mask

bbox = box(
    minx=0, 
    miny=0, 
    maxx=1250, 
    maxy=1250
    ) #xmin, ymin, xmax, ymax

with rasterio.open(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_cropped.tif") as src:
    out_image, out_transform = mask(src, [bbox], crop=True)
    out_meta = src.meta.copy()

show(out_image, cmap='terrain')
# Out:
# c:\Users\razer\AppData\Local\Programs\Python\Python311\Lib\site-packages\rasterio\__init__.py:317: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# <Axes: >

# %%
cropped_tiff = out_image

tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_cropped2.tif", cropped_tiff)
# Out:
# C:\Users\razer\AppData\Local\Temp\ipykernel_36608\176127628.py:3: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_cropped2.tif", cropped_tiff)

# %%
print('Min = ' + str(cropped_tiff.min()) + '     Max = ' + str(cropped_tiff.max()))
# Out:
# Min = -0.9908068     Max = 783.1697

# %%
file3 = rasterio.open(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_cropped2.tif")
dataset3 = file3.read()
# Out:
# c:\Users\razer\AppData\Local\Programs\Python\Python311\Lib\site-packages\rasterio\__init__.py:317: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import colors

norm = colors.Normalize(vmin=-3.5, vmax=2081)

value_range = 256

#Enter the hex codes of your desired colors here!
iceland_colormap = LinearSegmentedColormap.from_list('iceland', ['#ffffff','#CCDBE8', '#6088AB', '#305B80', '#223F59'], N=value_range)


fig = plt.figure(facecolor='#ffffff')
fig.set_size_inches(12, 12)
ax = plt.axes()
plt.imshow(dataset3[0], cmap=iceland_colormap)
ax.axis('off')
plt.show()

# %%
import earthpy.spatial as es
import earthpy.plot as ep

hillshade = es.hillshade(dataset3[0], azimuth=315, altitude=0)

ep.plot_bands(hillshade, cmap='gray')
plt.show()

# %%
import rasterio
from rasterio.plot import show
import tifffile as tiff


file = rasterio.open(r"C:\Users\razer\Desktop\topg_europa\tif\10_DEM_y40x50.tif")
dataset = file.read()
print(dataset.shape)

show(dataset, cmap='terrain')

image_array = dataset
tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_b.tif", image_array)
# Out:
# (1, 12001, 12001)
# C:\Users\razer\AppData\Local\Temp\ipykernel_36608\1428127231.py:13: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave(r"C:\Users\razer\Desktop\topg_europa\CURRENT_SCRIPT\hold_script_tifs\test_run_b.tif", image_array)

# %%
import rasterio
from rasterio.plot import show
import tifffile as tiff

# Open the raster file
file = rasterio.open(r"C:\Users\razer\Desktop\topg_europa\tif\10_DEM_y20x90.tif")
dataset = file.read()

# Extract bounding box
left, bottom, right, top = file.bounds
print("left:", left, "bottom", bottom, "right", right, "top", top)

# Create a name using the bounding box coordinates
filename = f"DEM_{top:.2f}N_{bottom:.2f}S_{left:.2f}E_{right:.2f}W.tif"

# # Save the dataset with the new name
# tiff.imsave(filename, dataset)

# Display
print(dataset.shape)
show(dataset, cmap='terrain')
# Out:
# left: 89.99958333333333 bottom 19.999583333333334 right 100.00041666666667 top 30.000416666666666
# (1, 12001, 12001)
# <Axes: >

# %%
from shapely.geometry import box
from rasterio.mask import mask

bbox = box(
    minx=0, 
    miny=0, 
    maxx=1200, 
    maxy=1200
    ) #xmin, ymin, xmax, ymax

with rasterio.open(r"C:\Users\razer\Desktop\topg_europa\tif\10_DEM_y20x90.tif") as src:
    out_image, out_transform = mask(src, [bbox], crop=True)
    out_meta = src.meta.copy()

show(out_image, cmap='terrain')
# Out:
# <Axes: >

# %%
print('Min = ' + str(out_image.min()) + '     Max = ' + str(out_image.max()))
# Out:
# Min = -70.09487     Max = 7489.596

# %%
import earthpy.spatial as es
import earthpy.plot as ep

hillshade = es.hillshade(out_image[0], azimuth=315, altitude=0)

ep.plot_bands(hillshade, cmap='gray')
plt.show()
